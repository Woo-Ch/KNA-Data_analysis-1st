# %% [markdown]
# 실습2. 이동 평균선으로 추세보기
# - 떨리는 원본 위에 매끈한 이동평균선을 겹쳐 추세 보기
#
# 목표
# - 떨리는 원본 위에 매끈한 이동평균선을 겹쳐 추세를 드러내기
#
# 단계
# - 창 크기 10으로 이동평균을 구하기
# - 원본과 이동평균을 한 그래프에 겹쳐 그리기
# - 범례를 붙이고 이동평균이 추세를 드러냄을 확인
#
# 예상 결과
# - 들쭉날쭉한 원본 사이로 매끈한 상승 추세선

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

sns.set_theme(style="whitegrid")

# 한글깨짐 해결
plt.rcParams["font.family"] = "Malgun Gothic"
plt.rcParams["axes.unicode_minus"] = False

df = pd.read_csv("../data/21_cmapss_fd001_sample.csv")

# %%
eng_02 = df[df["unit_nr"] == 2]

# 창 크기 10으로 이동평균을 구하기
moving_10 = eng_02["s_3"].rolling(window=10).mean()
print(moving_10.tail())
# 474    1606.594
# 475    1606.882
# 476    1606.546
# 477    1606.714
# 478    1606.413
print(moving_10.isna().sum().sum()) # 9

# 원본과 이동평균을 한 그래프에 겹쳐 그리기
# 범례를 붙이고 이동평균이 추세를 드러냄을 확인
plt.Figure(figsize=(5, 4))
plt.title("s_3 Window=10")
plt.plot(eng_02["time_cycles"], eng_02["s_3"], label="원천(row)", alpha=0.4)
plt.plot(eng_02["time_cycles"], moving_10, label="평활화")
plt.legend()
plt.xlabel("time_cycles")
plt.ylabel("s_3")
plt.show()
# Out:
# 474    1606.594
# 475    1606.882
# 476    1606.546
# 477    1606.714
# 478    1606.413
# Name: s_3, dtype: float64
# 9
